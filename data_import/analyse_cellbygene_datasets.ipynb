# %%
import pandas as pd
import seaborn as sns
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_html('../scratch/cellbygene.html')[0]

# %%
df['ncells'] = df.Cells.str.replace('.','').astype(float)
# Out:
# /var/folders/vf/nlxv5yvx0hd7j2bz6c_1j_qw0000gn/T/ipykernel_75656/2741403664.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['ncells'] = df.Cells.str.replace('.','').astype(float)

# %%
ax = plt.hist(df.ncells)
sns.despine()
plt.xlabel('nr of cells')
plt.ylabel('nr of studies')
# Out:
# Text(0, 0.5, 'nr of studies')

# %%
ax = plt.hist(df.query('ncells <= 500000').ncells)
sns.despine()
plt.xlabel('nr of cells')
plt.ylabel('nr of studies')
# Out:
# Text(0, 0.5, 'nr of studies')

# %%
df.sort_values('ncells', ascending = False)
# Out:
#                                     Datasets724 of 724                 Tissue  \
# 596  Survey of human embryonic developmentA human c...             15 tissues
# 499  Large-scale single-cell analysis reveals criti...              3 tissues
# 25   The single-cell lung cancer atlas (LuCA) -- ex...              6 tissues
# 274  multiplexed scRNA-seq of 1.2 million PBMCs fro...                  blood
# 273  Single-cell eQTL mapping identifies cell type ...                  blood
# ..                                                 ...                    ...
# 467  Human cortical expansion involves diversificat...              4 tissues
# 536  Human tonsil nonlymphoid cells scRNASingle-cel...                 tonsil
# 543  Spatiotemporal analysis of human intestinal de...                  ileum
# 542  Spatiotemporal analysis of human intestinal de...                  ileum
# 414  Healthy human liver: B cellsSingle-Cell, Singl...  caudate lobe of liver
#
# ...
